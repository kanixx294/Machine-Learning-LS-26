# %%
# Run this cell to install required libraries and import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns # Seaborn makes matplotlib plots look prettier!

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ### Step 1: Load the Data
# Use `pandas` to read the CSV file from the provided URL.

# %%
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

# TODO: use pd.read_csv() to load the data into a dataframe named 'df'
df = pd.read_csv(url)

# --- SANITY CHECK ---
assert 'df' in locals(), "Error: You didn't name your dataframe 'df'."
assert len(df) == 891, f"Error: Expected 891 rows, but got {len(df)}. Check your loading code."
print("✅ Data loaded perfectly! Move to the next step.")
df
# Out:
# ✅ Data loaded perfectly! Move to the next step.
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ### Step 2: Clean the Data
# Real-world data is messy. Let's find out what is missing and fix it.

# %%
# TODO: Print out the sum of null values for every column
# Hint: use df.isnull().sum()
print(df.isnull().sum())
# TODO: The 'Age' column has missing values. Fill the missing ages with the median age of the passengers.
mid = df['Age'].median()
df['Age'] = df['Age'].fillna(mid)

print("Missing values handled!")

# --- SANITY CHECK ---
assert df['Age'].isnull().sum() == 0, "Error: There are still missing values in the Age column!"
print("✅ Missing ages handled perfectly!")
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# Missing values handled!
# ✅ Missing ages handled perfectly!

# %% [markdown]
# ### Step 3: Visualize
# Time to draw some graphs. Create at least 3 plots below.
# Ideas: Survival rate by Gender, Passenger Class vs Survival, or an Age distribution histogram.

# %%
# TODO: Plot 1
# YOUR CODE HERE
plt.title("Age distribution Histogram")
plt.hist(df['Age'],edgecolor='black')
plt.ylabel('Frequency')
plt.xlabel('Age')
plt.show()
# TODO: Plot 2
# YOUR CODE HERE

x1 = len(df.loc[df['Sex'] == 'male'])
x2 = len(df.loc[(df['Sex'] == 'female')])

y1 = len(df.loc[(df['Sex'] == 'male') & (df['Survived']==1)]) * 100 / x1
y2 = len(df.loc[(df['Sex'] == 'female') & (df['Survived']==1)]) * 100 / x2

plt.title("Survival Percentage vs Gender")
plt.bar(['Male','Female'] , [y1,y2] , width = .5 , edgecolor = 'black')
plt.ylabel('Survival Percentage')
plt.xlabel('Gender')
plt.show()

# TODO: Plot 3
# YOUR CODE HERE

x1 = len(df.loc[df['Pclass'] == 1])
x2 = len(df.loc[df['Pclass'] == 2])
x3 = len(df.loc[df['Pclass'] == 3])

y1 = len(df.loc[(df['Pclass'] == 1) & (df['Survived']==1)]) * 100 / x1
y2 = len(df.loc[(df['Pclass'] == 2) & (df['Survived']==1)]) * 100 / x2
y3 = len(df.loc[(df['Pclass'] == 3) & (df['Survived']==1)]) * 100 / x3

plt.title("Survival Percentage vs Passenger Class")
plt.bar(['1st','2nd','3rd'] , [y1,y2,y3] , width = 0.5 , edgecolor = 'black')
plt.ylabel('Survival Percentage')
plt.xlabel('Passenger Class')
plt.show()
